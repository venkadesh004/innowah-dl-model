# %% [markdown]
# # Importing Libraries

# %%
import cv2
import numpy as np
import torch

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15305, done.
# remote: Total 15305 (delta 0), reused 0 (delta 0), pack-reused 15305
# Receiving objects: 100% (15305/15305), 14.13 MiB | 1.10 MiB/s, done.
# Resolving deltas: 100% (10501/10501), done.

# %%
model = torch.hub.load('./yolov5', 'custom', path='./yolov5s.pt', source='local')
# Out:
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.8 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
cv2.namedWindow("Frame", cv2.WINDOW_NORMAL)

cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = cap.read()
    
    if ret is False:
        break
        
    result = model(frame)
        
    cv2.imshow("Frame", np.squeeze(result.render()))
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyqt5 in /home/venkadesh/.local/lib/python3.10/site-packages (5.15.8)
# Collecting pyqt5
#   Downloading PyQt5-5.15.9-cp37-abi3-manylinux_2_17_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 1.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: lxml in /home/venkadesh/.local/lib/python3.10/site-packages (4.9.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.11 in /home/venkadesh/.local/lib/python3.10/site-packages (from pyqt5) (12.11.0)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /home/venkadesh/.local/lib/python3.10/site-packages (from pyqt5) (5.15.2)
# Installing collected packages: pyqt5
#   Attempting uninstall: pyqt5
#     Found existing installation: PyQt5 5.15.8
#     Uninstalling PyQt5-5.15.8:
#       Successfully uninstalled PyQt5-5.15.8
# Successfully installed pyqt5-5.15.9
# /bin/bash: line 1: cd: labelImg: No such file or directory

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# Receiving objects: 100% (2097/2097), 237.14 MiB | 511.00 KiB/s, done.
# remote: Total 2097 (delta 0), reused 4 (delta 0), pack-reused 2090
# Resolving deltas: 100% (1242/1242), done.

# %%
# !cd yolov5 && python3 train.py --img 320 --batch 16 --epochs 100 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.6 torch-1.13.1+cu117 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /home/venkadesh/Documents/LED_DETECTION_NEW/data/labels.cache...
# val: Scanning /home/venkadesh/Documents/LED_DETECTION_NEW/data/labels.cache... 7
#
# AutoAnchor: 5.04 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99         0G     0.1256    0.01108          0         12        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75   0.000225     0.0667   0.000133   2.18e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99         0G     0.1237    0.01226          0         20        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75    0.00027       0.08     0.0002   4.48e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99         0G     0.1214     0.0131          0         26        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75    0.00045      0.133   0.000271   7.21e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99         0G     0.1187    0.01255          0         19        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75   0.000811       0.24   0.000574   0.000122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99         0G     0.1176    0.01329          0         20        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75   0.000676        0.2   0.000482   0.000125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99         0G      0.116    0.01299          0         19        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75   0.000811       0.24   0.000827    0.00013
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99         0G     0.1143    0.01296          0         22        320: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75   0.000722      0.173    0.00166    0.00037
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99         0G     0.1087    0.01403          0         21        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75    0.00104      0.307   0.000829   0.000255
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99         0G     0.1103     0.0147          0         18        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75    0.00104      0.307   0.000811   0.000232
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99         0G     0.1053     0.0132          0         19        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75    0.00108       0.32   0.000787   0.000198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99         0G     0.1032    0.01365          0         11        320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         
320: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75      0.978      0.947      0.977      0.512
#
# 100 epochs completed in 0.485 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.3MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         74         75      0.978      0.947      0.977      0.513
# Results saved to runs/train/exp4

# %%
model = torch.hub.load('./yolov5', 'custom', path='yolov5/runs/train/exp4/weights/best.pt', force_reload=True, source='local')
# Out:
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.8 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
for i in range(1, 28):
    try:
        img = cv2.imread('./test/newOtherImage{}.jpg'.format(i))
        result = model(img)
    
        print(result)
    except:
        print("No image", i)
# Out:
# image 1/1: 468x1040 (no detections)
# Speed: 4.4ms pre-process, 140.5ms inference, 0.4ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.6ms pre-process, 85.1ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.6ms pre-process, 86.3ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 125.8ms inference, 0.4ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.8ms pre-process, 84.5ms inference, 1.0ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.8ms pre-process, 85.1ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 113.9ms inference, 1.0ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.8ms pre-process, 136.6ms inference, 0.4ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 3 leds
# Speed: 3.8ms pre-process, 149.5ms inference, 0.7ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 2 leds
# Speed: 1.8ms pre-process, 120.1ms inference, 0.8ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.9ms pre-process, 113.9ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 90.0ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.9ms pre-process, 81.6ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 83.3ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 88.0ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 84.3ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.9ms pre-process, 81.5ms inference, 0.7ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 90.1ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.8ms pre-process, 82.4ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.8ms pre-process, 81.9ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 91.3ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 84.4ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 81.9ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 90.9ms inference, 0.6ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.7ms pre-process, 81.9ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 1 led
# Speed: 1.7ms pre-process, 88.5ms inference, 0.7ms NMS per image at shape (1, 3, 288, 640)
# image 1/1: 468x1040 (no detections)
# Speed: 1.8ms pre-process, 103.2ms inference, 0.3ms NMS per image at shape (1, 3, 288, 640)

# %%
cv2.namedWindow("Frame", cv2.WINDOW_NORMAL)

cap = cv2.VideoCapture(0)

while True:
    
    ret, frame = cap.read()
    
    if ret is False:
        break
        
    result = model(frame)
        
    cv2.imshow("Frame", np.squeeze(result.render()))
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cv2.destroyAllWindows()
